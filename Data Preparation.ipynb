# %%
import os
import shutil
import glob
from tqdm import tqdm

# %% [markdown]
# #subject ID:
# xxx
#
# image number:
# xxx
#
# gender:
# 0 - male
# 1 - famale
#
# glasses:
# 0 - no
# 1 - yes
#
# eye state:
# 0 - close
# 1 - open
#
# reflections:
# 0 - none
# 1 - low
# 2 - high
#
# lighting conditions/image quality:
# 0 - bad
# 1 - good
#
# sensor type:
# 01 - RealSense SR300 640x480
# 02 - IDS Imaging, 1280x1024
# 03 - Aptina Imagin 752x480
#
# example:
# s001_00123_0_0_0_0_0_01.png

# %%
Raw_DIR=r'D:\TDL Project\Driver Drowsiness Detection\Raw Data'
for dirpath,dirname,filename in os.walk(Raw_DIR):
    for i in tqdm([f for f in filename if f.endswith('.png')]):
        if i.split('_')[4]=='0':
            shutil.copy(src=dirpath+'/'+i,dst=r'D:\TDL Project\Driver Drowsiness Detection\Prepared Data\Closed Eyes')
        elif i.split('_')[4]=='1':
            shutil.copy(src=dirpath+'/'+i,dst=r'D:\TDL Project\Driver Drowsiness Detection\Prepared Data\Open Eyes')
# Out:
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████████████████████████████████████████████| 10257/10257 [01:16<00:00, 134.30it/s]
